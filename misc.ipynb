# %%
import pandas as pd
import json

# %%
df = pd.read_csv('/Users/parlorsky/Downloads/v3_vacancies_type_id (1).csv')

# %%
first25 = [16, 27, 31, 33, 49, 52, 54, 58, 61, 69, 74, 91, 116, 119, 128, 134, 283, 336, 663, 706, 767, 783, 833, 836, 919]
second25 = [43, 23, 84, 85, 87, 124, 357, 561, 693, 712, 742, 765, 811, 812, 852, 853, 856, 873, 876, 888, 898, 917, 921, 954, 992]
third25 = [2, 35, 40, 86, 102, 111, 320, 324, 325, 326, 337, 698, 720, 734, 760, 804, 829, 850, 904, 941, 982, 994, 996, 997, 998]

# %%
bundles = first25 + second25 + third25

# %%
df
# Out:
#      vacancies_type_id                         vacancies_type_name  \
# 0                 -999              Не привязана к типовой позиции
# 1                    1                                   Бухгалтер
# 2                    2                           Ветеринарный врач
# 3                    3  Водитель автомобиля грузового/специального
# 4                    4               Водитель автомобиля легкового
# ..                 ...                                         ...
# 799               1019         Дежурный по железнодорожной станции
# 800               1020                         Инженер-теплотехник
# 801               1021            Машинист компрессорных установок
# 802               1022                Машинист (кочегар) котельной
# 803               1023     Машинист по стирке и ремонту спецодежды
#
#      vacancies_type_group_id  vacancies_type_group2_id  \
# 0                       -999                        -1
# 1                       -999                         5
# 2                       -999                         6
# 3                       -999                         8
# 4                       -999                         8
# ..                       ...                       ...
# 799                     -999                      -999
# 800                     -999                        14
# 801                     -999                      -999
# 802                     -999                      -999
# 803                     -999                      -999
#
#      education_type_group_id  code_opd  qualification  \
# 0                         -1        99              0
# 1                          2        34             99
# 2                          1        26             99
# 3                          2        32             99
# 4                          3        32             99
# ..                       ...       ...            ...
# 799                       -1        99             99
# 800                       -1        99             99
# 801                       -1        99             99
# 802                       -1        99             99
# 803                       -1        99             99
#
#                                            description  status  \
# 0                                Вакансии без привязки       1
# 1    Вакансия бухгалтера является сквозной для всех...       1
# 2    Вакансия ветеринарного врача включает в себя в...       1
# 3    Данная вакансия включает в себя не только води...       1
# 4    Данная вакансия включает в себя только водител...       1
# ..                                                 ...     ...
# 799  Дежурный по железнодорожной станции – это рабо...       1
# 800  Инженер-теплотехник - это специалист в области...       1
# 801  Машинист компрессорных установок - это специал...       1
# 802  Машинист (кочегар) котельной - это работник, к...       1
# 803  Машинист по стирке и ремонту спецодежды - это ...       1
#
#                  updated            bind_user  okz_id  view_type  quality  \
# 0    2023-03-15 23:35:46   Vladimir@vcot.info      -1          1      NaN
# 1    2023-04-11 17:00:08  r.elena97@vcot.info     127          1      NaN
# 2    2023-05-19 11:51:20  r.elena97@vcot.info      95          1      NaN
# 3    2021-12-01 00:00:00                  NaN     550          1      NaN
# 4    2021-12-01 00:00:00                  NaN     547          1      NaN
# ..                   ...                  ...     ...        ...      ...
# 799  2023-04-26 11:38:19  r.elena97@vcot.info     -99          1      NaN
# 800  2023-04-26 12:10:05  r.elena97@vcot.info     -99          1      NaN
# 801  2023-05-03 11:33:57  r.elena97@vcot.info     -99          1      NaN
# 802  2023-05-03 12:00:33  r.elena97@vcot.info     -99          1      NaN
# 803  2023-05-04 16:13:39  r.elena97@vcot.info     -99          1      NaN
#
#      experience_calc_type
# 0                     7.0
# 1                     7.0
# 2                     3.0
# 3                     2.0
# 4                     3.0
# ..                    ...
# 799                   NaN
# 800                   NaN
# 801                   NaN
# 802                   NaN
# 803                   NaN
#
# [804 rows x 15 columns]
